# %% [markdown]
# ### Primera clase de Python
#
# - En los Jupyter Notebook podemos crear celdas de Markdown
# - Y también podemos ejecutar código de Python
# - Así tendremos una libreta interactiva
#
# | Lenguaje | Uso principal              |
# | -------- | -------------------------- |
# | Python   | Ciencia de datos           |
# | Java     | Aplicaciones web           |
# | C#       | Aplicaciones de escritorio |

# %%
print("Bienvenidos a Python!")
# Out:
# Bienvenidos a Python!

# %%
print(f"Podemos crear varias salidas y ejecutar código dentro -> Dos + Dos = {2+2}")
# Out:
# Podemos crear varias salidas y ejecutar código dentro -> Dos + Dos = 4
