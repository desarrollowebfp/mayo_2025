# %% [markdown]
# ## Condicionales

# %%
espectadores = 4

if espectadores > 5:
    print("Abrimos la sala de cine")
else:
    print("No abrimos la sala de cine")
# Out:
# No abrimos la sala de cine

# %%
puntuacion = 8

if puntuacion >= 9:
    print("Obra maestra")
elif puntuacion >= 7:
    print("Notable")
elif puntuacion >= 4:
    print("Pasable")
elif puntuacion >= 2:
    print("Mala")
else:
    print("Mierdón")
# Out:
# Notable

# %%
dia = "viernes"
hora = 13

if dia == "viernes" and hora >= 15:
    print("Sesion especial de tarde")
elif dia == "sábado" or dia == "domingo":
    print("Horario de fin de semana")
else:
    print("Horario normal entre semana")
# Out:
# Horario normal entre semana

# %%
peliculas = []

if peliculas :
    print("Esta es la cartelera")
else:
    print("La cartelera está vacia")
    
# Falsy 
'''
  0
  0.0
  ""
  []
  {}
  None
  False  
'''
# Out:
# La cartelera está vacia

# %%
entradas_disponibles = 5
personas_en_cola = 3

if entradas_disponibles > 0:
    print("Podemos abrir la sala")
    if personas_en_cola > 0:
        print("Hay cola en la entrada")
    else:
        print("No hay cola en la entrada")
else:
    print("No abrimos la sala porque no hay entradas disponibles")
# Out:
# No abrimos la sala porque no hay entradas disponibles
