# %% [markdown]
# ### Librerias

# %%
from math import sqrt
from math import ceil

numero = 36
raiz_numero = math.sqrt(numero)
print(raiz_numero)

redondeo_hacia_arriba = math.ceil(5.3)
print(redondeo_hacia_arriba)
# Out:
# 6.0
# 6

# %%
import os

print(os.getcwd())
# Out:
# /Users/antoniorosalesmartinez/Dev/Repositorios/mayo_2025/PYTHON

# %%
import numpy as np

numeros = [10, 2, 5, 98, 3]

array_numeros = np.array(numeros)

print(np.mean(array_numeros))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import numpy as np
#       3 numeros = [10, 2, 5, 98, 3]
#       5 array_numeros = np.array(numeros)
#
# ModuleNotFoundError: No module named 'numpy'
